# %% [markdown]
# # Player Performance Prediction Walkthrough
#
# This notebook is a lightweight project walkthrough. Run the scripts below from the project root to generate data, train models, and inspect validation results.

# %%
from sports_predictor.data_collection import generate_sample_data
df = generate_sample_data()
df.head()

# %%
from sports_predictor.models import train_all_models
trained = train_all_models()
{sport: bundle.metrics for sport, bundle in trained.items()}
